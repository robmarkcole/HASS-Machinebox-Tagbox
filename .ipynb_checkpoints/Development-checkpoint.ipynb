# %% [markdown]
# https://machinebox.io/docs/tagbox/recognizing-images
#
# Have an attribute for every identified tag. Allow configurable tags which are always an attribute but have confidence = 0.0 if not detected, allowing a [template binary sensor](https://www.home-assistant.io/components/binary_sensor.template/).

# %%
import requests
import operator
import os
import io
import base64
import pathlib
import time
from PIL import Image
import json
from pprint import PrettyPrinter
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
import sys
print(sys.version)

ENDPOINT = "localhost:8080"
URL_CHECK = "http://{}/tagbox/check".format(ENDPOINT)
IMG_FILE = "dog.jpg"
FIG_SIZE = (12, 8)
ROUNDING_DECIMALS = 3

def print_json(json_data):
    PrettyPrinter().pprint(json_data)
# Out:
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 12:04:33)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
ls
# Out:
# Development.ipynb  README.md          dog.jpg
# LICENSE            custom_components/ tagbox_usage.png

# %%
img = plt.imread(IMG_FILE)
fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.imshow(img);

# %% [markdown]
# ## Post the file

# %%
# %%time
files = {
    'file': (IMG_FILE, open(IMG_FILE, 'rb')),
}

response = requests.post(URL_CHECK, files=files).json()
# Out:
# CPU times: user 7.48 ms, sys: 5.03 ms, total: 12.5 ms
# Wall time: 1.32 s

# %%
print_json(response)
# Out:
# {'custom_tags': [],
#  'success': True,
#  'tags': [{'confidence': 0.9220714569091797, 'tag': 'Pet'},
#           {'confidence': 0.8438391089439392, 'tag': 'Dog'},
#           {'confidence': 0.5935883522033691, 'tag': 'Mammal'},
#           {'confidence': 0.5837305188179016, 'tag': 'Animal'}]}

# %%
response['success']
# Out:
# True

# %%
response['tags']
# Out:
# [{'tag': 'Pet', 'confidence': 0.9220714569091797},
#  {'tag': 'Dog', 'confidence': 0.8438391089439392},
#  {'tag': 'Mammal', 'confidence': 0.5935883522033691},
#  {'tag': 'Animal', 'confidence': 0.5837305188179016}]

# %%
response['tags'][0]['tag'] # The most likely tag
# Out:
# 'Pet'

# %%
response['tags'][0]['confidence'] > 0.0
# Out:
# True

# %%
tags = {tag['tag']:round(tag['confidence'], ROUNDING_DECIMALS) for tag in response['tags']}
tags
# Out:
# {'Pet': 0.922, 'Dog': 0.844, 'Mammal': 0.594, 'Animal': 0.584}

# %%
confident_tags = [k for (k,v) in tags.items() if v > 0.8]

# %%
len(confident_tags)
# Out:
# 2

# %%
if response['custom_tags']:
    custom_tags = {tag['tag']:round(tag['confidence'], ROUNDING_DECIMALS) for tag in response['custom_tags']}
    tags.update(custom_tags)

# %%
tags
# Out:
# {'Pet': 0.922, 'Dog': 0.844, 'Mammal': 0.594, 'Animal': 0.584}

# %% [markdown]
# Get the most likely tag

# %%
max(tags.keys(), key=(lambda k: tags[k]))
# Out:
# 'Pet'

# %% [markdown]
# ## Custom tags
# Must post images with custom tags to recognise these objects.

# %%
TAG = 'kettle'
FILE_KETTLE = '/users/robincole/pictures/kettle.jpg'
img = plt.imread(FILE_KETTLE)
fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.imshow(img);

# %%
URL_TEACH = "http://{}/tagbox/teach?tag={}&id={}".format(ENDPOINT, TAG, FILE_KETTLE)

# %%
URL_TEACH
# Out:
# 'http://localhost:8080/tagbox/teach?tag=kettle&id=/users/robincole/pictures/kettle.jpg'

# %%
# %%time
files = {
    'file': (FILE_KETTLE, open(FILE_KETTLE, 'rb')),
}

response = requests.post(URL_TEACH, files=files).json()
# Out:
# CPU times: user 4.91 ms, sys: 5.57 ms, total: 10.5 ms
# Wall time: 3.34 s

# %%
print_json(response)
# Out:
# {'success': True}

# %% [markdown]
# Let's check it is tagged

# %%
FILE_KETTLE_2 = '/users/robincole/pictures/kettle_2.jpg'
img = plt.imread(FILE_KETTLE_2)
fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.imshow(img);

# %%
# %%time
files = {
    'file': (FILE_KETTLE_2, open(FILE_KETTLE_2, 'rb')),
}
response = requests.post(URL_CHECK, files=files).json()
# Out:
# CPU times: user 4.9 ms, sys: 3.56 ms, total: 8.47 ms
# Wall time: 1.51 s

# %%
print_json(response)
# Out:
# {'custom_tags': [{'confidence': 0.6131968686021452,
#                   'id': '/users/robincole/pictures/kettle.jpg',
#                   'tag': 'kettle'}],
#  'success': True,
#  'tags': [{'confidence': 0.8433592915534973, 'tag': 'Automotive exterior'},
#           {'confidence': 0.6332087516784668, 'tag': 'Wheel'},
#           {'confidence': 0.5640665292739868, 'tag': 'Bumper'}]}

# %% [markdown]
# It found the kettle with 61% confidence

# %%
if response['custom_tags']:
    custom_tags = {tag['tag']:tag['confidence'] for tag in response['custom_tags']}
custom_tags
# Out:
# {'kettle': 0.6131968686021452}

# %%
tags.update(custom_tags)
tags
# Out:
# {'Pet': 0.922,
#  'Dog': 0.844,
#  'Mammal': 0.594,
#  'Animal': 0.584,
#  'kettle': 0.6131968686021452}

# %% [markdown]
# ## Dev stuff

# %%
tags = ['kettle', 'keys']
default_tags = {tag: '0.0' for tag in tags}
default_tags
# Out:
# {'kettle': '0.0', 'keys': '0.0'}

# %%
def get_default_tags(tags_list):
    return {tag: '0.0' for tag in tags_list}

# %%
bla = {}
if bla:
    print(True)

# %%
timer_start = time.perf_counter()

# %%
elapsed = time.perf_counter() - timer_start

# %%
round(elapsed, ROUNDING_DECIMALS)
# Out:
# 0.385

# %%
tags = {'a':0, 'b':0}
max(tags.keys(), key=(lambda k: tags[k]))
# Out:
# 'a'

# %%
if tags:
    print(True)
# Out:
# True
